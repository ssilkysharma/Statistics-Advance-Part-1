# %% [markdown]
# Statistics Advance Part 1

# %% [markdown]
# 1.What is a random variable in probability theory?Ans:In probability theory, a random variable is a function that assigns a real number to each outcome in a sample space of a random experiment. It serves as a mathematical model to quantify uncertainty and variability in various phenomena

# %% [markdown]
# 2. What are the types of random variables?Ans:Types of Random Variables
# Discrete Random Variable
# Takes on a finite or countably infinite set of distinct values. Examples include the number of heads in a series of coin tosses or the sum of dice rolls. Its probability distribution is described by a probability mass function (PMF), which assigns a probability to each possible value.
#
# Continuous Random Variable
# Can assume any value within a given range or interval. Examples include measurements like height, weight, or temperature. Its probability distribution is described by a probability density function (PDF), where the probability of the variable falling within a specific range is given by the area under the curve over that interval.

# %% [markdown]
# 3. What is the difference between discrete and continuous distributions?Ans:Discrete Probability Distributions
# Nature of Outcomes: Discrete distributions deal with countable outcomes, such as integers or specific categories.
# Probability Function: Utilizes a Probability Mass Function (PMF), which assigns a probability to each distinct outcome. The sum of all probabilities equals 1.
# Examples:
# Number of heads in 10 coin tosses.
# Graphical Representation: Often depicted using bar charts, where each bar represents the probability of a specific outcome
# Continuous Probability Distributions
# Nature of Outcomes: Continuous distributions involve outcomes that can take any value within a given range, including fractions and decimals.
# Probability Function: Employs a Probability Density Function (PDF). The probability that a continuous random variable equals any specific value is zero; instead, probabilities are calculated over intervals. The total area under the curve of the PDF equals 1.
# Examples:
# Temperature readings over a day.
# Graphical Representation: Illustrated using smooth curves, where the area under the curve over a specific interval represents the probability of outcomes within that range.

# %% [markdown]
# 4.What are probability distribution functions (PDF)?Ans:A PDF is a function that describes the relative likelihood for a continuous random variable to take on a given value. Unlike discrete random variables, where probabilities are assigned to specific outcomes, a continuous random variable has an infinite number of possible values within any given interval. Therefore, the probability of the variable taking on any exact value is zero. Instead, probabilities are determined over intervals by calculating the area under the PDF curve within that range.

# %% [markdown]
# 5. How do cumulative distribution functions (CDF) differ from probability distribution functions (PDF)?
# Ans:
# **Feature**   -	**Probability Density Function (PDF)	Cumulative Distribution Function (CDF)**
# **Purpose**	Describes the likelihood of a random variable taking on a specific value.	Describes the probability that a random variable is less than or equal to a specific value.
# **Type of Variable**	Continuous random variables.	Continuous and discrete random variables.
# **Probability Calculation**	Probability over an interval: P(a≤X≤b)=∫abf(x) dxP(a \leq X \leq b) = \int_{a}^{b} f(x) \, dxP(a≤X≤b)=∫abf(x)dx.	Cumulative probability up to a point: F(x)=P(X≤x)F(x) = P(X \leq x)F(x)=P(X≤x).
# **Graphical Representation**	Curve, area under the curve represents probability.	Curve, shows cumulative probability.
# **Monotonicity**	Not necessarily monotonic.	Always non-decreasing.
# **Range**	f(x)≥0f(x) \geq 0f(x)≥0.	0≤F(x)≤10 \leq F(x) \leq 10≤F(x)≤1.

# %% [markdown]
# 6.What is a discrete uniform distribution?Ans:A discrete uniform distribution is a probability distribution where a finite set of distinct outcomes are equally likely to occur. Each outcome has the same probability of happening, making it a fundamental concept in probability theory

# %% [markdown]
# 7.What are the key properties of a Bernoulli distribution?Ans:Binary Outcomes: The random variable X can take only two values: 1 (success) or 0 (failure).
# Probability Mass Function (PMF): The PMF of a Bernoulli random variable is given by:
# P(X=x)=px(1−p)1−x,x∈{0,1}P(X = x) = p^x (1 - p)^{1 - x}, \quad x \in \{0, 1\}P(X=x)=px(1−p)1−x,x∈{0,1}
# where p is the probability of success.
# Expected Value (Mean): The mean or expected value of X is equal to the probability of success:
# E[X]=pE[X] = pE[X]=p
# Variance: The variance of X measures the spread of the distribution and is given by:
# Var(X)=p(1−p)\text{Var}(X) = p(1 - p)Var(X)=p(1−p)
# The variance is maximized when p=0.5p = 0.5p=0.5, indicating the highest uncertainty.

# %% [markdown]
# 8.What is the binomial distribution, and how is it used in probability?Ans:The binomial distribution is a fundamental concept in probability theory and statistics, used to model the number of successes in a fixed number of independent Bernoulli trials, each with the same probability of success. It is particularly useful for scenarios where there are two possible outcomes, such as success/failure, yes/no, or win/lose.The binomial distribution is widely used in various fields:
# Quality Control: Estimating the number of defective items in a batch.
# Finance: Assessing the probability of loan defaults.
# Marketing: Predicting the number of successful responses in a campaign.

# %% [markdown]
# 9.What is the Poisson distribution and where is it applied?Ans:The Poisson distribution is a discrete probability distribution that models the number of events occurring within a fixed interval of time or space, given that these events happen independently and at a constant average rate. It is particularly useful for modeling rare or infrequent events.example:Call Center Management: Predicting the number of incoming calls per hour to optimize staffing levels. For example, a call center receives an average of 10 calls per hour; the Poisson distribution can estimate the probability of receiving exactly 15 calls in an hour

# %% [markdown]
# 10.What is a continuous uniform distribution?Ans:A continuous uniform distribution, also known as a rectangular distribution, is a probability distribution where every outcome within a specified interval is equally likely. This distribution is commonly denoted as
# 𝑈
# (
# 𝑎
# ,
# 𝑏
# )
# U(a,b), where
# 𝑎
# a and
# 𝑏
# b represent the minimum and maximum values of the interval, respectively.

# %% [markdown]
# 11.What are the characteristics of a normal distribution?Ans:Symmetry
# The normal distribution is perfectly symmetrical around its mean. This means that the left half of the distribution is a mirror image of the right half.
# Bell-shaped Curve
# The graph of a normal distribution is often referred to as a "bell curve" due to its distinctive shape, which rises to a peak at the mean and then tapers off symmetrically on both sides.
# Equality of Mean, Median, and Mode
# In a perfectly normal distribution, the mean, median, and mode are all equal, located at the center of the distribution.
# Empirical Rule (68-95-99.7 Rule)
# In a normal distribution:
# Approximately 68% of the data falls within one standard deviation of the mean.
# Approximately 95% falls within two standard deviations.
# Approximately 99.7% falls within three standard deviations.

# %% [markdown]
# 12.What is the standard normal distribution, and why is it important?Ans:The standard normal distribution is a special case of the normal distribution, characterized by a mean (average) of 0 and a standard deviation (spread) of 1. It is symmetrical, bell-shaped, and serves as a fundamental concept in statistics, particularly for standardizing data and facilitating probability calculations.
# Application in Machine Learning and Data Science
# In machine learning, algorithms like logistic regression, k-means clustering, and principal component analysis (PCA) often assume or benefit from data that is normally distributed. Standardizing data to a standard normal distribution can enhance the performance and accuracy of these models.
# Standardization of Data (Z-Scores)
# By converting raw data into z-scores, we standardize different datasets, allowing for meaningful comparisons across diverse variables, even when they have different units or scales.

# %% [markdown]
# 13.What is the Central Limit Theorem (CLT), and why is it critical in statistics?Ans:The CLT posits that, regardless of the original distribution of a dataset, the sampling distribution of the sample mean approaches a normal distribution as the sample size increases. This principle justifies the use of normal distribution-based methods in inferential statistics.It is critical in statistics because:Foundation for Statistical Inference
# The CLT justifies the use of normal distribution-based methods, such as z-tests and t-tests, even when the underlying data is not normally distributed. This is crucial for making valid inferences about population parameters from sample data.
# Simplifies Complex Distributions
# By ensuring that sample means are approximately normally distributed, the CLT allows statisticians to apply standard statistical techniques without needing to know the exact distribution of the population.
# Enhances Precision of Estimates
# As sample size increases, the sample mean becomes a more accurate estimate of the population mean. This leads to more reliable statistical analyses and decision-making.
# Enables Confidence Interval Construction
# The CLT is essential for constructing confidence intervals, providing a range within which the true population parameter is likely to lie, thereby quantifying uncertainty in estimates.

# %% [markdown]
#  14.How does the Central Limit Theorem relate to the normal distribution?Ans:Convergence to Normality
# As the sample size increases, the sampling distribution of the sample mean becomes more closely approximated by a normal distribution, even if the original population distribution is not normal.
# Mean and Standard Deviation
# The mean of the sampling distribution of the sample mean will be equal to the population mean, and the standard deviation (known as the standard error) will be the population standard deviation divided by the square root of the sample size.
# Applicability Across Distributions
# The CLT applies to populations with finite variance and is robust to various types of distributions, including skewed or bimodal distributions.

# %% [markdown]
# 15.What is the application of Z statistics in hypothesis testing?Ans:Applications of Z-Statistics in Hypothesis Testing
# 1. One-Sample Z-Test
# Used to compare the sample mean to a known population mean. For example, a company might want to test if the average weight of a batch of products differs from the target weight. The null hypothesis (H₀) would state that there is no difference, and the alternative hypothesis (H₁) would state that there is a difference.
# 2. Two-Sample Z-Test
# Used to compare the means of two independent samples. For instance, comparing the average test scores of students from two different schools to determine if there is a significant difference in performance. The null hypothesis would state that the means are equal, and the alternative hypothesis would state that the means are not equal.
# 3. Z-Test for Proportions
# Used to compare sample proportions to known population proportions or to compare proportions between two independent samples. For example, a political analyst might use a Z-test for proportions to test whether the proportion of voters supporting a particular candidate in a sample matches the reported proportion from previous elections.

# %% [markdown]
# 16.> How do you calculate a Z-score, and what does it represent?Ans:The formula to calculate a Z-score is:
#
# 𝑍
# =
# 𝑋
# −
# 𝜇
# 𝜎
# Z=
# σ
# X−μ
# ​
#
# Where:
#
# 𝑋
# X = Raw score (the individual data point)
#
# 𝜇
# μ = Population mean
#
# 𝜎
# σ = Population standard deviation

# %% [markdown]
# 17.What are point estimates and interval estimates in statistics?Ans:
# Point Estimate
# A point estimate provides a single value as the best estimate of an unknown population parameter. It’s a specific statistic calculated from sample data, such as:
# Sample mean (x̄) as an estimate of the population mean (μ)
# Sample proportion (p̂) as an estimate of the population proportion (p)
# Sample standard deviation (s) as an estimate of the population standard deviation (σ)
# An interval estimate provides a range of values within which the population parameter is likely to fall, along with a specified level of confidence. This approach accounts for sampling variability and uncertainty. The most common form is the confidence interval.

# %% [markdown]
# 18.What is the significance of confidence intervals in statistical analysis?Ans:Quantifying Uncertainty
# CIs communicate the degree of uncertainty around an estimate. For instance, a 95% CI indicates that if the sampling process were repeated numerous times, approximately 95% of the calculated intervals would contain the true population parameter. This helps researchers understand the reliability of their estimates.
# 2. Enhancing Decision-Making
# In fields like medicine and economics, decisions often hinge on statistical findings. CIs provide a range of possible outcomes, allowing policymakers and practitioners to make informed choices while considering the variability and uncertainty in the data.

# %% [markdown]
# 19.What is the relationship between a Z-score and a confidence interval?Ans:The Z-score plays a pivotal role in constructing confidence intervals (CIs) by determining the critical value that defines the margin of error around a sample estimate. This relationship enables statisticians to quantify the uncertainty associated with sample data and make inferences about population parameters.

# %% [markdown]
# 20. How are Z-scores used to compare different distributions?Ans:Z-scores are essential for comparing data points across different distributions, especially when those distributions have varying means and standard deviations. By standardizing data, Z-scores provide a common scale, allowing for meaningful comparisons.Z-scores enable comparisons between data points from different distributions by standardizing them onto a common scale.

# %% [markdown]
# 21.What are the assumptions for applying the Central Limit Theorem?ans:Each data point in the sample must be independent of the others. This means that the outcome of one observation should not influence the outcome of another. In practice, this can be ensured by random sampling. If sampling without replacement, the sample size should be less than 10% of the total population to maintain independence.
# 2. Identically Distributed Variables
# All observations in the sample must come from the same probability distribution with the same parameters. This ensures that each sample mean is calculated under the same conditions, allowing for meaningful aggregation.
# 3. Sufficiently Large Sample Size
# A larger sample size increases the likelihood that the sampling distribution of the mean will approximate a normal distribution. While a sample size of 30 is often considered adequate, more skewed or heavy-tailed distributions may require larger samples to achieve normality.
# 4. Finite Variance
# The population from which the samples are drawn must have a finite variance. Distributions with infinite variance, such as the Cauchy distribution, do not satisfy this condition, and the CLT does not apply.
# 5. Random Sampling
# Samples should be selected randomly to ensure that every individual has an equal chance of being included. This randomness helps in obtaining a representative sample, thereby enhancing the reliability of the CLT.

# %% [markdown]
# 22. What is the concept of expected value in a probability distribution?Ans:The expected value (also known as the mean or expectation) of a probability distribution is the long-run average value of a random variable if an experiment is repeated many times. It represents what one would "expect" the outcome to be over the long term. Whether you're modeling die rolls, investment returns, or service times, the expected value provides crucial insight into the typical or "average" scenario.

# %% [markdown]
# 23How does a probability distribution relate to the expected outcome of a random variable?Ans:The probability distribution of a random variable describes all possible outcomes and their associated probabilities. The expected value (or mean) is derived directly from this distribution. It represents the long-run average outcome you'd expect if you repeated the random process many times.The expected value is a function of the distribution:
#
# For a discrete random variable
# 𝑋
# X with values
# 𝑥
# 𝑖
# x
# i
# ​
#   and probabilities
# 𝑝
# 𝑖
# p
# i
# ​
#  ,
# E[X] = \sum_i x_i\,p_i \]
# This sums each outcome weighted by its probability.
#
# For a continuous random variable with density
# 𝑓
# (
# 𝑥
# )
# f(x),
# E[X] = \int_{-\infty}^{\infty} x\,f(x)\,dx \]
# which integrates over all possible values.
#
# Intuitively, the expected value is the center of mass of the distribution:
# it reflects where outcomes cluster when averaged over many trials.

# %% [markdown]
# 1. Write a Python program to generate a random variable and display its value

# %%
import random

# Discrete random variable: integer between 1 and 100
random_int = random.randint(1, 100)
print("Random integer between 1 and 100:", random_int)

# Continuous random variable: float between 0 and 1
random_float = random.random()
print("Random float between 0.0 and 1.0:", random_float)

# Continuous uniform random variable between a and b
a, b = 2.5, 10.0
random_uniform = random.uniform(a, b)
print(f"Random float between {a} and {b}:", random_uniform)
# Out:
# Random integer between 1 and 100: 83
# Random float between 0.0 and 1.0: 0.09586131897076888
# Random float between 2.5 and 10.0: 3.694626982999454

# %% [markdown]
# 2.Generate a discrete uniform distribution using Python and plot the probability mass function (PMF)

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import randint

# Define a discrete uniform distribution from a to b inclusive
a, b = 1, 5
rv = randint(a, b+1)  # b+1 because upper bound is exclusive in scipy

# Possible outcomes
x = np.arange(a, b+1)

# Compute PMF values
pmf = rv.pmf(x)

# Plot the PMF
plt.figure(figsize=(5, 4))
plt.bar(x, pmf, color='skyblue', edgecolor='black')
plt.title(f'PMF of Discrete Uniform Distribution U({a}, {b})')
plt.xlabel('x')
plt.ylabel('P(X = x)')
plt.xticks(x)
plt.ylim(0, pmf.max() + 0.05)
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.show()

# %% [markdown]
# 3.Write a Python function to calculate the probability distribution function (PDF) of a Bernoulli distribution?

# %%
def bernoulli_pmf(x, p):
    """
    Compute the Bernoulli PMF:
      P(X = x) = p^x * (1-p)^(1-x)  for x in {0, 1}

    Args:
        x (int): Must be 0 or 1
        p (float): Probability of success, between 0 and 1

    Returns:
        float: The probability P(X = x)
    """
    if x not in (0, 1):
        return 0.0
    if not (0 <= p <= 1):
        raise ValueError("p must be between 0 and 1")
    # Formula from Bernoulli distribution
    return p**x * (1 - p)**(1 - x)

for x in [0, 1]:
    print(f"P(X={x}) = {bernoulli_pmf(x, p=0.6):.3f}")
# Out:
# P(X=0) = 0.400
# P(X=1) = 0.600

# %% [markdown]
# 4.Write a Python script to simulate a binomial distribution with n=10 and p=0.5, then plot its histogram

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import binom

# Simulation parameters
n = 10     # number of trials per experiment
p = 0.5    # probability of success
size = 10000  # number of experiments to simulate

# Generate binomial random samples
data = np.random.binomial(n, p, size)

# Plot histogram of simulated data
plt.figure(figsize=(8, 5))
counts, bins, patches = plt.hist(data, bins=np.arange(-0.5, n + 1.5, 1),
                                 density=True, alpha=0.6, color='skyblue',
                                 edgecolor='black', label='Empirical')

# Overlay theoretical PMF for comparison
x = np.arange(0, n + 1)
pmf = binom.pmf(x, n, p)
plt.vlines(x, 0, pmf, colors='red', linestyles='-', lw=2, label='Theoretical PMF')

plt.title(f'Binomial Distribution (n={n}, p={p})')
plt.xlabel('Number of successes')
plt.ylabel('Probability')
plt.legend()
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.xticks(x)
plt.show()

# %% [markdown]
#  5.Create a Poisson distribution and visualize it using Python

# %%
import numpy as np
from scipy.stats import poisson
import matplotlib.pyplot as plt

# Parameters
lambda_val = 4  # average number of events
k_max = 15      # maximum k-value to plot
sample_size = 1000

# 1. Compute PMF values
k_values = np.arange(0, k_max + 1)
pmf_values = poisson.pmf(k_values, mu=lambda_val)

# Plot PMF
plt.figure(figsize=(5,3))
plt.bar(k_values, pmf_values, color='violet', alpha=0.7, edgecolor='black')
plt.title(f'Poisson PMF (λ = {lambda_val})')
plt.xlabel('Number of events (k)')
plt.ylabel('P(X = k)')
plt.grid(alpha=0.3)
plt.show()

# %%
# 2. Simulate random data and overlay histogram
data = np.random.poisson(lam=lambda_val, size=sample_size)

plt.figure(figsize=(5,3))
plt.hist(data, bins=np.arange(-0.5, max(data)+1), density=True,
         alpha=0.6, color='skyblue', edgecolor='black', label='Simulated')

# Overlay theoretical PMF
plt.plot(k_values, pmf_values, 'ro-', label='Theoretical PMF')
plt.title(f'Poisson Sample vs Theoretical (λ = {lambda_val})')
plt.xlabel('Number of events')
plt.ylabel('Probability / Frequency')
plt.legend()
plt.grid(alpha=0.3)
plt.show()

# %% [markdown]
# 6.Write a Python program to calculate and plot the cumulative distribution function (CDF) of a discrete uniform distribution

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import randint

# Parameters for discrete uniform distribution
a, b = 1, 6

# Create the discrete uniform distribution: values in [a, b)
rv = randint(a, b+1)  # scipy defines randint as [a, b)

# Define the support (possible integer outcomes)
x = np.arange(a, b+1)

# Compute CDF at each value
cdf_values = rv.cdf(x)

# Plot the CDF: use a step function to represent jump behavior
plt.figure(figsize=(6, 4))
plt.step(x, cdf_values, where='post', linewidth=2, color='navy')
plt.scatter(x, cdf_values, color='navy')
plt.title(f'CDF of Discrete Uniform Distribution U({a}, {b})')
plt.xlabel('x')
plt.ylabel('F(x) = P(X ≤ x)')
plt.ylim(-0.05, 1.05)
plt.grid(axis='both', linestyle='--', alpha=0.6)
plt.xticks(x)
plt.show()

# %% [markdown]
# 7.Generate a continuous uniform distribution using NumPy and visualize it

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import uniform

# 📐 Parameters
a, b = 0, 10  # Lower and upper bounds
size = 5000  # Number of samples

# 1. Generate random samples
data = np.random.uniform(low=a, high=b, size=size)

# 2. Plot histogram (empirical PDF)
plt.figure(figsize=(6, 4))
counts, bins, patches = plt.hist(data, bins=30, density=True,
                                 alpha=0.6, color='skyblue',
                                 edgecolor='black', label='Empirical')

# 3. Overlay theoretical PDF
x = np.linspace(a, b, 150)
pdf = uniform.pdf(x, loc=a, scale=b - a)
plt.plot(x, pdf, 'r--', lw=2, label='Theoretical PDF')

plt.title(f'Continuous Uniform Distribution U({a}, {b})')
plt.xlabel('Value')
plt.ylabel('Probability Density')
plt.legend()
plt.grid(alpha=0.3)
plt.show()

# %% [markdown]
# 8.Simulate data from a normal distribution and plot its histogram

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# 1. Generate samples from a normal distribution
mu, sigma = 0, 1  # mean and standard deviation
N = 10000         # number of samples
data = np.random.normal(loc=mu, scale=sigma, size=N)

# 2. Plot the normalized histogram (empirical PDF)
count, bins, patches = plt.hist(data, bins=30, density=True, alpha=0.6, color='skyblue',
                                edgecolor='black', label='Histogram (empirical)')

# 3. Compute the theoretical PDF and overlay it
bin_centers = 0.5*(bins[1:] + bins[:-1])
pdf = norm.pdf(bin_centers, loc=mu, scale=sigma)
plt.plot(bin_centers, pdf, 'r--', linewidth=2, label='Normal PDF')

# 4. Customize and show the plot
plt.title(f'Normal Distribution (μ={mu}, σ={sigma})')
plt.xlabel('Value')
plt.ylabel('Probability Density')
plt.legend()
plt.grid(alpha=0.3)
plt.show()

# %% [markdown]
#  9.Write a Python function to calculate Z-scores from a dataset and plot them

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import zscore

def calculate_and_plot_z_scores(data):
    # Calculate Z-scores using scipy.stats.zscore
    z_scores = zscore(data)

    # Plotting the histogram of Z-scores
    plt.figure(figsize=(8, 6))
    plt.hist(z_scores, bins=30, edgecolor='black', alpha=0.7)
    plt.title('Histogram of Z-Scores')
    plt.xlabel('Z-Score')
    plt.ylabel('Frequency')
    plt.grid(True)
    plt.show()

    return z_scores

# Example usage
data = [3, 9, 23, 43, 53, 4, 5, 30, 35, 50, 70, 150, 6, 7, 8, 9, 10]
z_scores = calculate_and_plot_z_scores(data)
print("Z-Scores:", z_scores)
# Out:
# Z-Scores: [-0.7574907  -0.59097335 -0.20243286  0.35262498  0.6301539  -0.72973781
#  -0.70198492 -0.00816262  0.13060185  0.54689523  1.10195307  3.32218443
#  -0.67423202 -0.64647913 -0.61872624 -0.59097335 -0.56322046]

# %% [markdown]
#  10.Implement the Central Limit Theorem (CLT) using Python for a non-normal distribution

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Parameters
population_size = 10000
sample_size = 30
num_samples = 1000

# Generate a population from an exponential distribution
population = np.random.exponential(scale=1.0, size=population_size)

# Function to compute sample means
def compute_sample_means(population, sample_size, num_samples):
    sample_means = []
    for _ in range(num_samples):
        sample = np.random.choice(population, size=sample_size, replace=False)
        sample_means.append(np.mean(sample))
    return sample_means

# Compute sample means
sample_means = compute_sample_means(population, sample_size, num_samples)

# Plot the population distribution
plt.figure(figsize=(14, 6))

plt.subplot(1, 2, 1)
plt.hist(population, bins=50, color='skyblue', edgecolor='black', alpha=0.7)
plt.title('Population Distribution (Exponential)')
plt.xlabel('Value')
plt.ylabel('Frequency')

# Plot the distribution of sample means
plt.subplot(1, 2, 2)
plt.hist(sample_means, bins=50, color='lightgreen', edgecolor='black', alpha=0.7, density=True)
plt.title(f'Sampling Distribution of Sample Means (n={sample_size})')
plt.xlabel('Sample Mean')
plt.ylabel('Density')

# Overlay a normal distribution for comparison
mean_of_sample_means = np.mean(sample_means)
std_dev_of_sample_means = np.std(sample_means)
x = np.linspace(min(sample_means), max(sample_means), 100)
plt.plot(x, norm.pdf(x, mean_of_sample_means, std_dev_of_sample_means), 'r-', lw=2, label='Normal Approximation')
plt.legend()

plt.tight_layout()
plt.show()

# Display summary statistics
print(f"Mean of sample means: {mean_of_sample_means}")
print(f"Standard deviation of sample means: {std_dev_of_sample_means}")
# Out:
# Mean of sample means: 1.0054000448829652
# Standard deviation of sample means: 0.19027508204984298

# %% [markdown]
# **11 to 14 questions are missing from the assignment or the numbering is wrong**

# %% [markdown]
# 15.Simulate multiple samples from a normal distribution and verify the Central Limit Theorem

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Parameters
population_size = 10000
sample_size = 30
num_samples = 1000

# Generate a population from an exponential distribution
population = np.random.exponential(scale=1.0, size=population_size)

# Function to compute sample means
def compute_sample_means(population, sample_size, num_samples):
    sample_means = []
    for _ in range(num_samples):
        sample = np.random.choice(population, size=sample_size, replace=False)
        sample_means.append(np.mean(sample))
    return sample_means

# Compute sample means
sample_means = compute_sample_means(population, sample_size, num_samples)

# Plot the population distribution
plt.figure(figsize=(14, 6))

plt.subplot(1, 2, 1)
plt.hist(population, bins=50, color='skyblue', edgecolor='black', alpha=0.7)
plt.title('Population Distribution (Exponential)')
plt.xlabel('Value')
plt.ylabel('Frequency')

# Plot the distribution of sample means
plt.subplot(1, 2, 2)
plt.hist(sample_means, bins=50, color='lightgreen', edgecolor='black', alpha=0.7, density=True)
plt.title(f'Sampling Distribution of Sample Means (n={sample_size})')
plt.xlabel('Sample Mean')
plt.ylabel('Density')

# Overlay a normal distribution for comparison
mean_of_sample_means = np.mean(sample_means)
std_dev_of_sample_means = np.std(sample_means)
x = np.linspace(min(sample_means), max(sample_means), 100)
plt.plot(x, norm.pdf(x, mean_of_sample_means, std_dev_of_sample_means), 'r--', linewidth=2, label='Normal Approximation')
plt.legend()

plt.tight_layout()
plt.show()

# Display summary statistics
print(f"Mean of sample means: {mean_of_sample_means}")
print(f"Standard deviation of sample means: {std_dev_of_sample_means}")
# Out:
# Mean of sample means: 0.9969597447246303
# Standard deviation of sample means: 0.18549257092361443

# %% [markdown]
# 16. Write a Python function to calculate and plot the standard normal distribution (mean = 0, std = 1)?

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

def plot_standard_normal():
    x = np.linspace(-5, 5, 1000)  # Generate 1000 points from -5 to 5
    y = norm.pdf(x, loc=0, scale=1)  # Compute the PDF for standard normal distribution

    plt.figure(figsize=(8, 6))
    plt.plot(x, y, label=r'$\mu=0, \sigma=1$', color='blue')
    plt.title('Standard Normal Distribution')
    plt.xlabel('X')
    plt.ylabel('Probability Density')
    plt.grid(True)
    plt.legend()
    plt.show()

plot_standard_normal()

# %% [markdown]
# 17.Generate random variables and calculate their corresponding probabilities using the binomial distribution?

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import binom

# Parameters
n = 10  # Number of trials
p = 0.5  # Probability of success
size = 10000  # Number of random variables to generate

# Generate random variables
random_vars = np.random.binomial(n, p, size)

# Calculate probabilities (PMF) for each unique outcome
unique, counts = np.unique(random_vars, return_counts=True)
probabilities = counts / size

# Plot histogram of generated random variables
plt.figure(figsize=(10, 6))
plt.hist(random_vars, bins=np.arange(n+2)-0.5, density=True, alpha=0.6, color='g', label='Empirical PMF')

# Overlay theoretical PMF
x = np.arange(n+1)
plt.plot(x, binom.pmf(x, n, p), 'bo', ms=8, label='Theoretical PMF')

plt.title('Binomial Distribution: Empirical vs Theoretical PMF')
plt.xlabel('Number of Successes')
plt.ylabel('Probability')
plt.legend()
plt.grid(True)
plt.show()

# Display empirical probabilities
for k, prob in zip(unique, probabilities):
    print(f"Empirical P(X = {k}) = {prob:.4f}")
# Out:
# Empirical P(X = 0) = 0.0009
# Empirical P(X = 1) = 0.0094
# Empirical P(X = 2) = 0.0432
# Empirical P(X = 3) = 0.1208
# Empirical P(X = 4) = 0.2012
# Empirical P(X = 5) = 0.2465
# Empirical P(X = 6) = 0.2060
# Empirical P(X = 7) = 0.1163
# Empirical P(X = 8) = 0.0453
# Empirical P(X = 9) = 0.0097
# Empirical P(X = 10) = 0.0007

# %% [markdown]
# 18.Write a Python program to calculate the Z-score for a given data point and compare it to a standard normal distribution

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Parameters
mean = 100
std_dev = 15
x = 130

# Calculate Z-score
z_score = (x - mean) / std_dev

# Calculate cumulative probability
p_value = norm.cdf(z_score)

# Plot standard normal distribution
x_vals = np.linspace(-4, 4, 1000)
y_vals = norm.pdf(x_vals)
plt.plot(x_vals, y_vals, label='Standard Normal Distribution')

# Highlight the Z-score
plt.axvline(z_score, color='r', linestyle='--', label=f'Z = {z_score:.2f}')
plt.title('Standard Normal Distribution with Z-Score')
plt.xlabel('Z')
plt.ylabel('Probability Density')
plt.legend()
plt.grid(True)
plt.show()

# Output
print(f"Z-score for x = {x}: {z_score:.2f}")
print(f"Cumulative probability (P(Z ≤ {z_score:.2f})): {p_value:.4f}")
# Out:
# Z-score for x = 130: 2.00
# Cumulative probability (P(Z ≤ 2.00)): 0.9772

# %% [markdown]
# 19. Implement hypothesis testing using Z-statistics for a sample dataset

# %%
import numpy as np
import scipy.stats as stats
import math

# Given data
sample_mean = 980
population_mean = 1000
population_std_dev = 80
sample_size = 64
alpha = 0.05

# Step 1: Calculate the Z-Score
standard_error = population_std_dev / math.sqrt(sample_size)
z_score = (sample_mean - population_mean) / standard_error

# Step 2: Determine the critical Z-Value for a two-tailed test
z_critical = stats.norm.ppf(1 - alpha/2)

# Step 3: Make the decision
if abs(z_score) > z_critical:
    result = "Reject the null hypothesis: There is enough evidence that the average bulb life is less than 1000 hours."
else:
    result = "Fail to reject the null hypothesis: Not enough evidence that the average bulb life is less than 1000 hours."

# Output results
print(f"Calculated Z-score: {z_score:.3f}")
print(f"Critical Z-value: ±{z_critical:.3f}")
print(result)
# Out:
# Calculated Z-score: -2.000
# Critical Z-value: ±1.960
# Reject the null hypothesis: There is enough evidence that the average bulb life is less than 1000 hours.

# %% [markdown]
#  20.Create a confidence interval for a dataset using Python and interpret the result

# %%
import numpy as np
import scipy.stats as stats

# Sample data: Weights of 100 individuals
np.random.seed(42)
data = np.random.normal(loc=70, scale=10, size=100)

# Calculate sample statistics
sample_mean = np.mean(data)
sample_std = np.std(data, ddof=1)
sample_size = len(data)

# Define confidence level
confidence_level = 0.95

# Calculate standard error
standard_error = sample_std / np.sqrt(sample_size)

# Determine the critical value (z-score) for the confidence level
z_critical = stats.norm.ppf((1 + confidence_level) / 2)

# Calculate margin of error
margin_of_error = z_critical * standard_error

# Calculate confidence interval
ci_lower = sample_mean - margin_of_error
ci_upper = sample_mean + margin_of_error

print(f"Sample Mean: {sample_mean:.2f}")
print(f"Sample Standard Deviation: {sample_std:.2f}")
print(f"Critical Z-value: {z_critical:.2f}")
print(f"Margin of Error: {margin_of_error:.2f}")
print(f"{int(confidence_level * 100)}% Confidence Interval: ({ci_lower:.2f}, {ci_upper:.2f})")
# Out:
# Sample Mean: 68.96
# Sample Standard Deviation: 9.08
# Critical Z-value: 1.96
# Margin of Error: 1.78
# 95% Confidence Interval: (67.18, 70.74)

# %% [markdown]
#  21.Generate data from a normal distribution, then calculate and interpret the confidence interval for its mean

# %%
import numpy as np
import scipy.stats as stats

# Generate random data from a normal distribution
np.random.seed(42)
data = np.random.normal(loc=70, scale=10, size=100)

# Calculate sample statistics
sample_mean = np.mean(data)
sample_std = np.std(data, ddof=1)  # ddof=1 for sample standard deviation
sample_size = len(data)

# Define confidence level
confidence_level = 0.95

# Calculate standard error
standard_error = sample_std / np.sqrt(sample_size)

# Determine the critical value (z-score) for the confidence level
z_critical = stats.norm.ppf((1 + confidence_level) / 2)

# Calculate margin of error
margin_of_error = z_critical * standard_error

# Calculate confidence interval
ci_lower = sample_mean - margin_of_error
ci_upper = sample_mean + margin_of_error

print(f"Sample Mean: {sample_mean:.2f}")
print(f"Sample Standard Deviation: {sample_std:.2f}")
print(f"Critical Z-value: {z_critical:.2f}")
print(f"Margin of Error: {margin_of_error:.2f}")
print(f"{int(confidence_level * 100)}% Confidence Interval: ({ci_lower:.2f}, {ci_upper:.2f})")
# Out:
# Sample Mean: 68.96
# Sample Standard Deviation: 9.08
# Critical Z-value: 1.96
# Margin of Error: 1.78
# 95% Confidence Interval: (67.18, 70.74)

# %% [markdown]
# 22.Write a Python script to calculate and visualize the probability density function (PDF) of a normal distribution

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Parameters for the normal distribution
mean = 0
std_dev = 1
sample_size = 10000

# Generate random data from a normal distribution
data = np.random.normal(loc=mean, scale=std_dev, size=sample_size)

# Create a range of values for plotting the PDF
x_values = np.linspace(mean - 4*std_dev, mean + 4*std_dev, 1000)

# Calculate the PDF for the normal distribution
pdf_values = norm.pdf(x_values, loc=mean, scale=std_dev)

# Plotting the histogram of the data
plt.figure(figsize=(8, 6))
plt.hist(data, bins=30, density=True, alpha=0.6, color='g', label='Histogram of Samples')

# Plotting the PDF
plt.plot(x_values, pdf_values, 'k-', lw=2, label='Normal Distribution PDF')

# Adding labels and title
plt.title('Normal Distribution: PDF and Histogram')
plt.xlabel('Value')
plt.ylabel('Density')
plt.legend()

# Show the plot
plt.grid(True)
plt.show()

# %% [markdown]
#  23.Use Python to calculate and interpret the cumulative distribution function (CDF) of a Poisson distribution

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import poisson

# Parameters
lambda_val = 5  # Average rate (λ)
k_values = np.arange(0, 16)  # Values for which we want to calculate the CDF

# Calculate CDF for each k
cdf_values = poisson.cdf(k_values, mu=lambda_val)

# Display CDF values
for k, cdf in zip(k_values, cdf_values):
    print(f"P(X ≤ {k}) = {cdf:.4f}")

# Plotting the CDF
plt.step(k_values, cdf_values, where='post', label=f'Poisson CDF (λ={lambda_val})')
plt.xlabel('Number of Events (k)')
plt.ylabel('Cumulative Probability')
plt.title('Poisson Distribution CDF')
plt.grid(True)
plt.legend()
plt.show()
# Out:
# P(X ≤ 0) = 0.0067
# P(X ≤ 1) = 0.0404
# P(X ≤ 2) = 0.1247
# P(X ≤ 3) = 0.2650
# P(X ≤ 4) = 0.4405
# P(X ≤ 5) = 0.6160
# P(X ≤ 6) = 0.7622
# P(X ≤ 7) = 0.8666
# P(X ≤ 8) = 0.9319
# P(X ≤ 9) = 0.9682
# P(X ≤ 10) = 0.9863
# P(X ≤ 11) = 0.9945
# P(X ≤ 12) = 0.9980
# P(X ≤ 13) = 0.9993
# P(X ≤ 14) = 0.9998
# P(X ≤ 15) = 0.9999

# %% [markdown]
# 24.Simulate a random variable using a continuous uniform distribution and calculate its expected value

# %%
import numpy as np

# Parameters for the uniform distribution
a = 2  # Lower bound
b = 8  # Upper bound

# Generate a random sample from the uniform distribution
sample_size = 10000
random_samples = np.random.uniform(a, b, sample_size)

# Calculate the sample mean
sample_mean = np.mean(random_samples)

# Theoretical expected value
theoretical_mean = (a + b) / 2

print(f"Sample Mean: {sample_mean:.4f}")
print(f"Theoretical Expected Value: {theoretical_mean:.4f}")
# Out:
# Sample Mean: 5.0454
# Theoretical Expected Value: 5.0000

# %% [markdown]
# 25 Write a Python program to compare the standard deviations of two datasets and visualize the difference

# %%
import numpy as np
import matplotlib.pyplot as plt

# Sample datasets
data1 = np.array([12, 15, 14, 10, 18, 20, 22, 25, 30, 35])
data2 = np.array([5, 7, 6, 4, 8, 9, 10, 12, 14, 15])

# Calculate standard deviations
std_dev1 = np.std(data1)
std_dev2 = np.std(data2)

# Print standard deviations
print(f"Standard Deviation of Data1: {std_dev1:.2f}")
print(f"Standard Deviation of Data2: {std_dev2:.2f}")

# Plotting histograms
plt.figure(figsize=(12, 6))

# Histogram for Data1
plt.subplot(1, 2, 1)
plt.hist(data1, bins=5, alpha=0.7, color='blue', edgecolor='black')
plt.title('Histogram of Data1')
plt.xlabel('Value')
plt.ylabel('Frequency')

# Histogram for Data2
plt.subplot(1, 2, 2)
plt.hist(data2, bins=5, alpha=0.7, color='green', edgecolor='black')
plt.title('Histogram of Data2')
plt.xlabel('Value')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# Box plots
plt.figure(figsize=(6, 6))
plt.boxplot([data1, data2], labels=['Data1', 'Data2'], patch_artist=True, boxprops=dict(facecolor='lightblue', color='blue'), flierprops=dict(markerfacecolor='red', marker='o', markersize=8))
plt.title('Box Plot Comparison')
plt.ylabel('Value')
plt.grid(True)
plt.show()
# Out:
# Standard Deviation of Data1: 7.63
# Standard Deviation of Data2: 3.55
# /tmp/ipython-input-29-3811707910.py:38: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([data1, data2], labels=['Data1', 'Data2'], patch_artist=True, boxprops=dict(facecolor='lightblue', color='blue'), flierprops=dict(markerfacecolor='red', marker='o', markersize=8))

# %% [markdown]
# 26. Calculate the range and interquartile range (IQR) of a dataset generated from a normal distribution

# %%
import numpy as np

# Parameters for the normal distribution
mean = 0
std_dev = 1
sample_size = 1000

# Generate random data from a normal distribution
data = np.random.normal(loc=mean, scale=std_dev, size=sample_size)

# Calculate Range
data_range = np.max(data) - np.min(data)

# Calculate Interquartile Range (IQR)
q1 = np.percentile(data, 25)
q3 = np.percentile(data, 75)
iqr = q3 - q1

print(f"Range: {data_range:.2f}")
print(f"Interquartile Range (IQR): {iqr:.2f}")
# Out:
# Range: 7.28
# Interquartile Range (IQR): 1.41

# %% [markdown]
# 27.Implement Z-score normalization on a dataset and visualize its transformation

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler

# Generate a dataset from a normal distribution
np.random.seed(42)
data = np.random.normal(loc=50, scale=15, size=1000)

# Calculate original mean and standard deviation
original_mean = np.mean(data)
original_std = np.std(data)

# Apply Z-score normalization
scaler = StandardScaler()
data_normalized = scaler.fit_transform(data.reshape(-1, 1)).flatten()

# Calculate normalized mean and standard deviation
normalized_mean = np.mean(data_normalized)
normalized_std = np.std(data_normalized)

# Print original and normalized statistics
print(f"Original Mean: {original_mean:.2f}, Original Std Dev: {original_std:.2f}")
print(f"Normalized Mean: {normalized_mean:.2f}, Normalized Std Dev: {normalized_std:.2f}")

# Plotting the original and normalized data
plt.figure(figsize=(12, 6))

# Original data histogram
plt.subplot(1, 2, 1)
plt.hist(data, bins=30, color='skyblue', edgecolor='black')
plt.title('Original Data Distribution')
plt.xlabel('Value')
plt.ylabel('Frequency')

# Normalized data histogram
plt.subplot(1, 2, 2)
plt.hist(data_normalized, bins=30, color='lightgreen', edgecolor='black')
plt.title('Normalized Data Distribution')
plt.xlabel('Z-score')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()
# Out:
# Original Mean: 50.29, Original Std Dev: 14.68
# Normalized Mean: 0.00, Normalized Std Dev: 1.00

# %% [markdown]
# 28 Write a Python function to calculate the skewness and kurtosis of a dataset generated from a normal distribution

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import skew, kurtosis

def analyze_distribution(data):
    """
    Calculate and print the skewness and kurtosis of the given dataset.
    Also, visualize the distribution with a histogram and a normal curve.
    """
    # Calculate skewness and kurtosis
    skewness_value = skew(data)
    kurtosis_value = kurtosis(data)

    # Print the results
    print(f"Skewness: {skewness_value:.4f}")
    print(f"Kurtosis: {kurtosis_value:.4f}")

    # Plotting the histogram
    plt.figure(figsize=(10, 6))
    plt.hist(data, bins=30, alpha=0.7, color='blue', edgecolor='black', density=True)

    # Plotting the normal curve
    xmin, xmax = plt.xlim()
    x = np.linspace(xmin, xmax, 100)
    p = 1/(np.sqrt(2 * np.pi * np.std(data)**2)) * np.exp(- 0.5 * ( x - np.mean(data))**2 / np.std(data)**2)
    plt.plot(x, p, 'k', linewidth=2)

    plt.title('Histogram and Normal Curve')
    plt.xlabel('Data Values')
    plt.ylabel('Density')
    plt.grid(True)
    plt.show()

# Generate a dataset from a normal distribution
np.random.seed(42)
data = np.random.normal(loc=0, scale=1, size=1000)

# Analyze the distribution
analyze_distribution(data)
# Out:
# Skewness: 0.1168
# Kurtosis: 0.0662
